# %% [markdown]
# ## Run Gene Set Enrichment Analysis (GSEA) Enrichr using gseapy for the each broad and specific cell-type's individual age associated latent factors

# %%
# !date
# Out:
# Fri Jun 21 15:38:28 EDT 2024

# %% [markdown]
# #### import libraries

# %%
from pandas import read_csv, concat, DataFrame
from pickle import load as pkl_load
from gseapy.enrichr import Enrichr
from time import sleep
from re import match

# %% [markdown]
# #### set notebook variables

# %%
# parameters
project = 'aging_phase2'
latent_type = 'all'

# directories
wrk_dir = '/labshare/raph/datasets/adrd_neuro/brain_aging/phase2'
results_dir = f'{wrk_dir}/results'
figures_dir = f'{wrk_dir}/figures'

# in files
assoc_file = f'{results_dir}/{project}.latent.age_glm.csv'
loadings_pickle = f'{results_dir}/{project}.latent.loadings.pkl'

# out files
results_file = f'{figures_dir}/{project}.cell_type_latents.{latent_type}.gsea_enrichr.csv'

# constants and variables
DEBUG = True
marker_sets = ['MSigDB_Hallmark_2020',
               'GO_Biological_Process_2023', 
               'GO_Cellular_Component_2023',
               'GO_Molecular_Function_2023', 
               'KEGG_2019_Human']
PAUSE_AMT = 2
ALPHA = 0.05

# %%
if DEBUG:
    print(assoc_file)
    print(loadings_pickle)
    print(results_file)
# Out:
# /labshare/raph/datasets/adrd_neuro/brain_aging/phase2/results/aging_phase2.latent.age_glm.csv
# /labshare/raph/datasets/adrd_neuro/brain_aging/phase2/results/aging_phase2.latent.loadings.pkl
# /labshare/raph/datasets/adrd_neuro/brain_aging/phase2/figures/aging_phase2.cell_type_latents.all.gsea_enrichr.csv

# %% [markdown]
# #### functions

# %%
def find_enrichment(name: str, genes: list, sets,
                    verbose: bool=False) -> DataFrame:
    enr_res = gseapy.enrichr(gene_list=genes,
                             organism='Human',
                             gene_sets=sets,
                             cutoff=0.5)
    enr_res.results['factor'] = name    
    if verbose:
        print(f'full {sets} results shape{enr_res.results.shape}')        
        sig = enr_res.results.loc[enr_res.results['Adjusted P-value'] <= 0.05]
        print(f'significant {sets} results shape{sig.shape}')
        display(sig)
    return enr_res.results

# %% [markdown]
# ### load input data

# %% [markdown]
# #### load the latent factor age associations

# %%
age_glm_df = read_csv(assoc_file, index_col=0)
print(f'shape of age_glm_df is {age_glm_df.shape}')
age_glm_df['key_name'] = age_glm_df.cell_type + ':' + age_glm_df.feature
if DEBUG:
    display(age_glm_df.sample(4))
    print(f'age_glm_df has {age_glm_df.key_name.nunique()} keys')
# Out:
# shape of age_glm_df is (491, 9)
#   feature       coef     stderr         z       p-value      type cell_type  \
# 0   NMF_0 -16.021782  12.974903 -1.234829  2.168943e-01  specific     InN-5
# 1   ICA_1  -2.226917   4.883931 -0.455968  6.484129e-01  specific     ExN-6
# 4   NMF_4  34.703340   6.494610  5.343407  9.121578e-08  specific    InN-10
# 0   NMF_0  29.282517   5.909427  4.955221  7.224811e-07     broad     Micro
#
#   model_type    fdr_bh      key_name
# 0        nmf  0.341330   InN-5:NMF_0
# 1        ica  0.786101   ExN-6:ICA_1
# 4        nmf  0.000001  InN-10:NMF_4
# 0        nmf  0.000006   Micro:NMF_0
# age_glm_df has 491 keys

# %% [markdown]
# ### load the latent factor's feature loadings

# %%
with open(loadings_pickle, 'rb') as pkl_file:
    feature_loadings = pkl_load(pkl_file)
print(f'loadings_pickle has {len(feature_loadings)} entries')
# Out:
# loadings_pickle has 491 entries

# %% [markdown]
# ### subset the latent factor to only those with a statistically significant age association

# %%
age_glm_df = age_glm_df.loc[age_glm_df.fdr_bh <= ALPHA]
print(f'shape of age_glm_df is {age_glm_df.shape}')
if DEBUG:
    display(age_glm_df.sample(4))
    display(age_glm_df.model_type.value_counts())
# Out:
# shape of age_glm_df is (196, 10)
#   feature       coef     stderr         z       p-value      type cell_type  \
# 0   PCA_0   1.015366   0.160244  6.336367  2.352460e-10  specific   Astro-1
# 1   NMF_1  32.594619  11.110218  2.933752  3.348921e-03  specific    ExN-14
# 5   ICA_5 -18.999449   4.604183 -4.126563  3.682254e-05  specific    ExN-15
# 0   PCA_0   1.334802   0.374338  3.565768  3.627919e-04  specific    ExN-14
#
#   model_type        fdr_bh       key_name
# 0        pca  4.687992e-09  Astro-1:PCA_0
# 1        nmf  1.174514e-02   ExN-14:NMF_1
# 5        ica  2.259983e-04   ExN-15:ICA_5
# 0        pca  1.746381e-03   ExN-14:PCA_0
# nmf    82
# ica    66
# pca    48
# Name: model_type, dtype: int64

# %% [markdown]
# ### build the gene sets to use per age associated latent factor

# %%
# %%time
latent_features = {}
# regex pattern for match ATAC peaks naming format
pattern = r'^chr.*:.*-.*$'
for factor in age_glm_df.key_name.unique():
    loading = feature_loadings.get(factor)
    age_features = []
    for feature, weight in loading.items():
        # # # only add genes not ATAC peaks, very large and slow otherwise
        if not match(pattern, feature):
            age_features.append(feature)
    if len(age_features) > 0:
        latent_features[factor] = list(set(age_features))
    if DEBUG:
        print(f'{factor} has {len(age_features)} genes')
print(f'latent_features has {len(latent_features)} keys')
# Out:
# OD-0:PCA_0 has 2 genes
# OD-0:NMF_0 has 37 genes
# OD-0:NMF_2 has 57 genes
# OD-0:ICA_1 has 146 genes
# OD-0:ICA_2 has 107 genes
# ExN-8:PCA_1 has 87 genes
# ExN-8:NMF_1 has 140 genes
# ExN-8:NMF_2 has 121 genes
# ExN-8:NMF_3 has 137 genes
# ExN-8:ICA_0 has 119 genes
# ExN-8:ICA_4 has 121 genes
# ExN-14:PCA_0 has 0 genes
# ExN-14:NMF_1 has 0 genes
# ExN-14:NMF_3 has 14 genes
# ExN-14:ICA_0 has 80 genes
# ExN-14:ICA_3 has 52 genes
# OPC-4:PCA_0 has 0 genes
# OPC-4:NMF_1 has 0 genes
# OPC-4:NMF_5 has 29 genes
# OPC-4:ICA_0 has 127 genes
# OPC-4:ICA_3 has 121 genes
# Micro-3:PCA_0 has 2 genes
# Micro-3:PCA_1 has 239 genes
# Micro-3:NMF_0 has 63 genes
# Micro-3:NMF_1 has 3 genes
# Micro-3:NMF_2 has 417 genes
# Micro-3:NMF_4 has 209 genes
# Micro-3:ICA_3 has 199 genes
# Micro-3:ICA_4 has 233 genes
# Micro-3:ICA_5 has 345 genes
# ExN-9:PCA_0 has 0 genes
# ExN-9:NMF_4 has 1 genes
# ExN-9:ICA_5 has 144 genes
# InN-5:PCA_1 has 161 genes
# InN-5:PCA_2 has 167 genes
# InN-5:PCA_4 has 156 genes
# InN-5:NMF_1 has 182 genes
# InN-5:NMF_2 has 151 genes
# InN-5:ICA_0 has 146 genes
# InN-5:ICA_2 has 151 genes
# InN-5:ICA_3 has 157 genes
# InN-12:PCA_1 has 63 genes
# InN-12:PCA_4 has 67 genes
# InN-12:NMF_1 has 59 genes
# InN-12:NMF_3 has 68 genes
# InN-12:ICA_2 has 65 genes
# ExN-6:PCA_0 has 8 genes
# ExN-6:NMF_0 has 12 genes
# ExN-6:NMF_1 has 150 genes
# ExN-6:NMF_2 has 46 genes
# ExN-6:ICA_0 has 147 genes
# ExN-6:ICA_2 has 132 genes
# ExN-6:ICA_3 has 101 genes
# InN-10:PCA_1 has 36 genes
# InN-10:PCA_4 has 34 genes
# InN-10:NMF_2 has 43 genes
# InN-10:NMF_4 has 36 genes
# InN-10:ICA_0 has 39 genes
# InN-10:ICA_3 has 41 genes
# InN-10:ICA_4 has 36 genes
# Astro-1:PCA_0 has 3 genes
# Astro-1:NMF_5 has 5 genes
# Astro-1:ICA_1 has 170 genes
# Astro-1:ICA_4 has 148 genes
# PeriVasc-20:PCA_0 has 0 genes
# PeriVasc-20:PCA_3 has 40 genes
# PeriVasc-20:NMF_2 has 8 genes
# PeriVasc-20:NMF_3 has 29 genes
# PeriVasc-20:NMF_5 has 52 genes
# PeriVasc-20:ICA_1 has 42 genes
# PeriVasc-20:ICA_5 has 53 genes
# InN-23:PCA_1 has 71 genes
# InN-23:NMF_1 has 60 genes
# InN-23:NMF_5 has 64 genes
# InN-23:ICA_0 has 68 genes
# InN-23:ICA_2 has 77 genes
# ExN-7:PCA_0 has 0 genes
# ExN-7:PCA_1 has 390 genes
# ExN-7:NMF_0 has 4 genes
# ExN-7:NMF_2 has 380 genes
# ExN-7:NMF_3 has 8 genes
# ExN-7:NMF_4 has 0 genes
# ExN-7:ICA_1 has 370 genes
# ExN-7:ICA_2 has 320 genes
# InN-18:PCA_0 has 129 genes
# InN-18:PCA_1 has 164 genes
# InN-18:PCA_2 has 201 genes
# InN-18:NMF_1 has 191 genes
# InN-18:NMF_2 has 177 genes
# InN-18:ICA_1 has 186 genes
# InN-18:ICA_2 has 190 genes
# ExN-2:PCA_0 has 0 genes
# ExN-2:NMF_0 has 5 genes
# ExN-2:NMF_1 has 208 genes
# ExN-2:NMF_2 has 0 genes
# ExN-2:ICA_2 has 170 genes
# ExN-2:ICA_4 has 73 genes
# ExN-2:ICA_5 has 132 genes
# OD-21:PCA_0 has 0 genes
# OD-21:NMF_0 has 1 genes
# OD-21:NMF_1 has 0 genes
# OD-21:NMF_2 has 43 genes
# OD-21:ICA_1 has 37 genes
# ExN-15:PCA_1 has 162 genes
# ExN-15:PCA_2 has 161 genes
# ExN-15:NMF_0 has 165 genes
# ExN-15:NMF_1 has 164 genes
# ExN-15:ICA_4 has 173 genes
# ExN-15:ICA_5 has 190 genes
# ExN-25:PCA_0 has 10 genes
# ExN-25:NMF_0 has 14 genes
# ExN-25:NMF_2 has 12 genes
# ExN-25:NMF_3 has 13 genes
# ExN-25:ICA_0 has 11 genes
# ExN-25:ICA_1 has 10 genes
# ExN-25:ICA_2 has 13 genes
# ExN-19:PCA_0 has 42 genes
# ExN-19:PCA_1 has 41 genes
# ExN-19:PCA_2 has 42 genes
# ExN-19:NMF_0 has 49 genes
# ExN-19:NMF_1 has 58 genes
# ExN-19:NMF_3 has 35 genes
# ExN-19:ICA_1 has 49 genes
# ExN-19:ICA_2 has 48 genes
# ExN-19:ICA_3 has 45 genes
# VLMC-22:PCA_0 has 0 genes
# VLMC-22:PCA_1 has 1 genes
# VLMC-22:NMF_0 has 1 genes
# VLMC-22:NMF_2 has 0 genes
# VLMC-22:NMF_3 has 0 genes
# VLMC-22:ICA_0 has 1 genes
# VLMC-22:ICA_2 has 1 genes
# InN-13:PCA_0 has 0 genes
# InN-13:PCA_1 has 0 genes
# InN-13:PCA_4 has 0 genes
# InN-13:NMF_0 has 0 genes
# InN-13:NMF_2 has 0 genes
# InN-13:NMF_5 has 0 genes
# InN-13:NMF_6 has 0 genes
# InN-13:NMF_7 has 0 genes
# InN-13:NMF_8 has 0 genes
# InN-13:NMF_9 has 0 genes
# InN-13:ICA_1 has 0 genes
# InN-13:ICA_3 has 0 genes
# InN-13:ICA_6 has 0 genes
# OD:PCA_0 has 1 genes
# OD:NMF_0 has 71 genes
# OD:NMF_1 has 117 genes
# OD:ICA_3 has 111 genes
# ExN:PCA_0 has 0 genes
# ExN:NMF_0 has 11 genes
# ExN:NMF_2 has 473 genes
# ExN:NMF_3 has 1 genes
# ExN:ICA_1 has 488 genes
# ExN:ICA_4 has 326 genes
# OPC:PCA_0 has 0 genes
# OPC:NMF_4 has 9 genes
# OPC:ICA_4 has 172 genes
# Micro:PCA_0 has 1 genes
# Micro:PCA_1 has 457 genes
# Micro:NMF_0 has 338 genes
# Micro:NMF_2 has 495 genes
# Micro:NMF_3 has 251 genes
# Micro:NMF_5 has 0 genes
# Micro:ICA_0 has 443 genes
# Micro:ICA_3 has 342 genes
# Micro:ICA_4 has 303 genes
# InN:PCA_1 has 134 genes
# InN:PCA_2 has 234 genes
# InN:NMF_0 has 267 genes
# InN:NMF_1 has 144 genes
# InN:NMF_3 has 248 genes
# InN:ICA_0 has 200 genes
# InN:ICA_1 has 147 genes
# InN:ICA_2 has 254 genes
# InN:ICA_5 has 213 genes
# Astro:PCA_0 has 1 genes
# Astro:NMF_3 has 130 genes
# Astro:NMF_4 has 11 genes
# Astro:ICA_1 has 378 genes
# Astro:ICA_3 has 241 genes
# PeriVasc:PCA_0 has 0 genes
# PeriVasc:PCA_5 has 69 genes
# PeriVasc:NMF_1 has 87 genes
# PeriVasc:NMF_3 has 21 genes
# PeriVasc:NMF_4 has 87 genes
# PeriVasc:NMF_5 has 45 genes
# PeriVasc:ICA_0 has 88 genes
# PeriVasc:ICA_3 has 49 genes
# VLMC:PCA_0 has 0 genes
# VLMC:NMF_0 has 0 genes
# VLMC:NMF_3 has 0 genes
# VLMC:NMF_5 has 0 genes
# VLMC:NMF_7 has 0 genes
# VLMC:ICA_1 has 1 genes
# VLMC:ICA_5 has 1 genes
# latent_features has 159 keys
# CPU times: user 349 ms, sys: 975 µs, total: 350 ms
# Wall time: 348 ms

# %% [markdown]
# ### run the GSEA Enrichr

# %% [markdown]
# #### if debugging see available GSEA libraries

# %%
if DEBUG:
    import gseapy
    gene_set_names = gseapy.get_library_name(organism='Human')
    print(gene_set_names)
# Out:
# ['ARCHS4_Cell-lines', 'ARCHS4_IDG_Coexp', 'ARCHS4_Kinases_Coexp', 'ARCHS4_TFs_Coexp', 'ARCHS4_Tissues', 'Achilles_fitness_decrease', 'Achilles_fitness_increase', 'Aging_Perturbations_from_GEO_down', 'Aging_Perturbations_from_GEO_up', 'Allen_Brain_Atlas_10x_scRNA_2021', 'Allen_Brain_Atlas_down', 'Allen_Brain_Atlas_up', 'Azimuth_2023', 'Azimuth_Cell_Types_2021', 'BioCarta_2013', 'BioCarta_2015', 'BioCarta_2016', 'BioPlanet_2019', 'BioPlex_2017', 'CCLE_Proteomics_2020', 'CORUM', 'COVID-19_Related_Gene_Sets', 'COVID-19_Related_Gene_Sets_2021', 'Cancer_Cell_Line_Encyclopedia', 'CellMarker_2024', 'CellMarker_Augmented_2021', 'ChEA_2013', 'ChEA_2015', 'ChEA_2016', 'ChEA_2022', 'Chromosome_Location', 'Chromosome_Location_hg19', 'ClinVar_2019', 'DSigDB', 'Data_Acquisition_Method_Most_Popular_Genes', 'DepMap_WG_CRISPR_Screens_Broad_CellLines_2019', 'DepMap_WG_CRISPR_Screens_Sanger_CellLines_2019', 'Descartes_Cell_Types_and_Tissue_2021', 'Diabetes_Perturbations_GEO_2022', 'DisGeNET', 'Disease_Perturbations_from_GEO_down', 'Disease_Perturbations_from_GEO_up', 'Disease_Signatures_from_GEO_down_2014', 'Disease_Signatures_from_GEO_up_2014', 'DrugMatrix', 'Drug_Perturbations_from_GEO_2014', 'Drug_Perturbations_from_GEO_down', 'Drug_Perturbations_from_GEO_up', 'ENCODE_Histone_Modifications_2013', 'ENCODE_Histone_Modifications_2015', 'ENCODE_TF_ChIP-seq_2014', 'ENCODE_TF_ChIP-seq_2015', 'ENCODE_and_ChEA_Consensus_TFs_from_ChIP-X', 'ESCAPE', 'Elsevier_Pathway_Collection', 'Enrichr_Libraries_Most_Popular_Genes', 'Enrichr_Submissions_TF-Gene_Coocurrence', 'Enrichr_Users_Contributed_Lists_2020', 'Epigenomics_Roadmap_HM_ChIP-seq', 'FANTOM6_lncRNA_KD_DEGs', 'GO_Biological_Process_2013', 'GO_Biological_Process_2015', 'GO_Biological_Process_2017', 'GO_Biological_Process_2017b', 'GO_Biological_Process_2018', 'GO_Biological_Process_2021', 'GO_Biological_Process_2023', 'GO_Cellular_Component_2013', 'GO_Cellular_Component_2015', 'GO_Cellular_Component_2017', 'GO_Cellular_Component_2017b', 'GO_Cellular_Component_2018', 'GO_Cellular_Component_2021', 'GO_Cellular_Component_2023', 'GO_Molecular_Function_2013', 'GO_Molecular_Function_2015', 'GO_Molecular_Function_2017', 'GO_Molecular_Function_2017b', 'GO_Molecular_Function_2018', 'GO_Molecular_Function_2021', 'GO_Molecular_Function_2023', 'GTEx_Aging_Signatures_2021', 'GTEx_Tissue_Expression_Down', 'GTEx_Tissue_Expression_Up', 'GTEx_Tissues_V8_2023', 'GWAS_Catalog_2019', 'GWAS_Catalog_2023', 'GeDiPNet_2023', 'GeneSigDB', 'Gene_Perturbations_from_GEO_down', 'Gene_Perturbations_from_GEO_up', 'Genes_Associated_with_NIH_Grants', 'Genome_Browser_PWMs', 'GlyGen_Glycosylated_Proteins_2022', 'HDSigDB_Human_2021', 'HDSigDB_Mouse_2021', 'HMDB_Metabolites', 'HMS_LINCS_KinomeScan', 'HomoloGene', 'HuBMAP_ASCT_plus_B_augmented_w_RNAseq_Coexpression', 'HuBMAP_ASCTplusB_augmented_2022', 'HumanCyc_2015', 'HumanCyc_2016', 'Human_Gene_Atlas', 'Human_Phenotype_Ontology', 'IDG_Drug_Targets_2022', 'InterPro_Domains_2019', 'Jensen_COMPARTMENTS', 'Jensen_DISEASES', 'Jensen_TISSUES', 'KEA_2013', 'KEA_2015', 'KEGG_2013', 'KEGG_2015', 'KEGG_2016', 'KEGG_2019_Human', 'KEGG_2019_Mouse', 'KEGG_2021_Human', 'KOMP2_Mouse_Phenotypes_2022', 'Kinase_Perturbations_from_GEO_down', 'Kinase_Perturbations_from_GEO_up', 'L1000_Kinase_and_GPCR_Perturbations_down', 'L1000_Kinase_and_GPCR_Perturbations_up', 'LINCS_L1000_CRISPR_KO_Consensus_Sigs', 'LINCS_L1000_Chem_Pert_Consensus_Sigs', 'LINCS_L1000_Chem_Pert_down', 'LINCS_L1000_Chem_Pert_up', 'LINCS_L1000_Ligand_Perturbations_down', 'LINCS_L1000_Ligand_Perturbations_up', 'Ligand_Perturbations_from_GEO_down', 'Ligand_Perturbations_from_GEO_up', 'MAGMA_Drugs_and_Diseases', 'MAGNET_2023', 'MCF7_Perturbations_from_GEO_down', 'MCF7_Perturbations_from_GEO_up', 'MGI_Mammalian_Phenotype_2013', 'MGI_Mammalian_Phenotype_2017', 'MGI_Mammalian_Phenotype_Level_3', 'MGI_Mammalian_Phenotype_Level_4', 'MGI_Mammalian_Phenotype_Level_4_2019', 'MGI_Mammalian_Phenotype_Level_4_2021', 'MSigDB_Computational', 'MSigDB_Hallmark ...

# %%
# %%time
results = []
for latent, gene_list in latent_features.items():
    print(f'\n########### {latent} ###########')
    for gene_set in marker_sets:
        print(f'\n+++++++++++ {gene_set} +++++++++++')
        results.append(find_enrichment(latent, list(gene_list), gene_set, verbose=False))
        sleep(PAUSE_AMT)
# Out:
# ########### OD-0:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD-0:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD-0:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD-0:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD-0:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-8:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-8:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-8:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-8:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-8:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-8:ICA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-14:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-14:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-14:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OPC-4:NMF_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OPC-4:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OPC-4:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro-3:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro-3:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro-3:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro-3:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro-3:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro-3:NMF_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro-3:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro-3:ICA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro-3:ICA_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-9:NMF_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-9:ICA_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-5:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-5:PCA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-5:PCA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-5:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-5:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-5:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-5:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-5:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-12:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-12:PCA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-12:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-12:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-12:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-6:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-6:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-6:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-6:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-6:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-6:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-6:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-10:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-10:PCA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-10:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-10:NMF_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-10:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-10:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-10:ICA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Astro-1:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Astro-1:NMF_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Astro-1:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Astro-1:ICA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc-20:PCA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc-20:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc-20:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc-20:NMF_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc-20:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc-20:ICA_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-23:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-23:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-23:NMF_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-23:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-23:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-7:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-7:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-7:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-7:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-7:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-7:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-18:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-18:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-18:PCA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-18:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-18:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-18:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN-18:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-2:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-2:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-2:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-2:ICA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-2:ICA_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD-21:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD-21:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD-21:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-15:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-15:PCA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-15:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-15:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-15:ICA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-15:ICA_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-25:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-25:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-25:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-25:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-25:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-25:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-25:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-19:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-19:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-19:PCA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-19:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-19:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-19:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-19:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-19:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN-19:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### VLMC-22:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### VLMC-22:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### VLMC-22:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### VLMC-22:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OD:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### ExN:ICA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OPC:NMF_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### OPC:ICA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro:NMF_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Micro:ICA_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN:PCA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN:PCA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN:NMF_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN:ICA_2 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### InN:ICA_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Astro:PCA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Astro:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Astro:NMF_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Astro:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### Astro:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc:PCA_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc:NMF_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc:NMF_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc:NMF_4 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc:NMF_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc:ICA_0 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### PeriVasc:ICA_3 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### VLMC:ICA_1 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++
#
# ########### VLMC:ICA_5 ###########
#
# +++++++++++ MSigDB_Hallmark_2020 +++++++++++
#
# +++++++++++ GO_Biological_Process_2023 +++++++++++
#
# +++++++++++ GO_Cellular_Component_2023 +++++++++++
#
# +++++++++++ GO_Molecular_Function_2023 +++++++++++
#
# +++++++++++ KEGG_2019_Human +++++++++++

# %% [markdown]
# #### convert full enrichment results into combined data frame

# %%
results_df = concat(results)
print(f'full results shape {results_df.shape}')
if DEBUG:
    display(results_df.sample(5))
    display(results_df.Gene_set.value_counts())
# Out:
# full results shape (130635, 11)
#                        Gene_set  \
# 42   GO_Cellular_Component_2023
# 23   GO_Cellular_Component_2023
# 344  GO_Biological_Process_2023
# 729  GO_Biological_Process_2023
# 485  GO_Biological_Process_2023
#
#                                                   Term Overlap   P-value  \
# 42             Endocytic Vesicle Membrane (GO:0030666)   3/159  0.240247
# 23                  Golgi Medial Cisterna (GO:0005797)    2/10  0.020764
# 344  Monoatomic Cation Transmembrane Transport (GO:...   2/281  0.310144
# 729       Peptidyl-Serine Phosphorylation (GO:0018105)   2/158  0.585534
# 485  Positive Regulation Of T Cell Mediated Cytotox...    1/33  0.546366
#
#      Adjusted P-value Old P-value Old Adjusted P-value  Odds Ratio  \
# 42           0.698393           0                    0    1.797711
# 23           0.200715           0                    0   10.733516
# 344          0.425697           0                    0    1.805073
# 729          0.768413           0                    0    1.021263
# 485          0.999988           0                    0    1.290718
#
#      Combined Score            Genes        factor
# 42         2.563692  RAB35;CYBB;CD36     InN:ICA_5
# 23        41.587551    YIPF1;ST3GAL1   Micro:PCA_1
# 344        2.113230  SLC12A1;CACNA1G  ExN-14:ICA_0
# 729        0.546612     PRKCQ;STK32B     InN:NMF_3
# 485        0.780194             FADD     ExN:NMF_2
# GO_Biological_Process_2023    86237
# GO_Molecular_Function_2023    18389
# KEGG_2019_Human               11508
# GO_Cellular_Component_2023    11341
# MSigDB_Hallmark_2020           3160
# Name: Gene_set, dtype: int64

# %% [markdown]
# ### clean-up the GO term entity

# %%
results_df['Gene_set'] = results_df.Gene_set.str.replace('GO_','')
results_df['Gene_set'] = results_df.Gene_set.str.replace('_2020','')
results_df['Gene_set'] = results_df.Gene_set.str.replace('_2023','')
results_df['Gene_set'] = results_df.Gene_set.str.replace('_2019_Human','')
results_df['Term'] = results_df.Gene_set + ': ' + results_df.Term
print(f'shape of GSEA post Term naming cleanup {results_df.shape}')
if DEBUG:
    display(results_df.sample(5))
# Out:
# shape of GSEA post Term naming cleanup (130635, 11)
#                Gene_set                                               Term  \
# 457  Biological_Process  Biological_Process: Cytoskeleton Organization ...
# 289  Biological_Process  Biological_Process: Membrane Organization (GO:...
# 347  Biological_Process  Biological_Process: Synapse Organization (GO:0...
# 29   Biological_Process  Biological_Process: Cellular Response To Inter...
# 49                 KEGG                         KEGG: Pancreatic secretion
#
#     Overlap   P-value  Adjusted P-value Old P-value Old Adjusted P-value  \
# 457   1/111  0.296135          0.356914           0                    0
# 289   1/167  0.279153          0.323433           0                    0
# 347   2/131  0.714387          0.999996           0                    0
# 29     1/10  0.022768          0.179748           0                    0
# 49     2/98  0.164003          0.517119           0                    0
#
#      Odds Ratio  Combined Score        Genes         factor
# 457    2.907185        3.537865       DIAPH1  Micro-3:NMF_0
# 289    3.138079        4.004169        REEP1   InN-10:ICA_0
# 347    0.799434        0.268874    MUSK;MYOT    ExN-7:NMF_2
# 29    49.246914      186.270813       IL15RA    ExN-6:NMF_2
# 49     2.819064        5.096495  ADCY3;ADCY2  Astro-1:ICA_4

# %% [markdown]
# #### how many are statistically significant

# %%
sig_results = results_df.loc[results_df['Adjusted P-value'] <= ALPHA]
print(f'{sig_results.shape[0]} terms were detected')
if sig_results.shape[0] < 20:
    display(sig_results.sort_values('Odds Ratio', ascending=False))
else:
    display(sig_results.sort_values('Odds Ratio', ascending=False).head(20))
# Out:
# 949 terms were detected
#              Gene_set                                               Term  \
# 0  Biological_Process  Biological_Process: Resolution Of Recombinatio...
# 0  Molecular_Function  Molecular_Function: 5'-Flap Endonuclease Activ...
# 1  Molecular_Function  Molecular_Function: Flap Endonuclease Activity...
# 2  Molecular_Function  Molecular_Function: Crossover Junction DNA End...
# 3  Molecular_Function  Molecular_Function: Endodeoxyribonuclease Acti...
# 4  Molecular_Function  Molecular_Function: DNA Endonuclease Activity,...
# 0  Biological_Process  Biological_Process: Columnar/Cuboidal Epitheli...
# 0  Molecular_Function  Molecular_Function: cAMP-dependent Protein Kin...
# 2  Biological_Process  Biological_Process: Positive Regulation Of Spi...
# 1  Biological_Process  Biological_Process: Positive Regulation Of Mit...
# 1  Molecular_Function  Molecular_Function: Protein Kinase A Catalytic...
# 0  Biological_Process  Biological_Process: Regulation Of cAMP-depende...
# 3  Biological_Process  Biological_Process: Mitotic Recombination (GO:...
# 5  Molecular_Function  Molecular_Function: Four-Way Junction DNA Bind...
# 4  Biological_Process  Biological_Process: Regulation Of Mitotic Cell...
# 1  Biological_Process  Biological_Process: Epithelial Cell Developmen...
# 5  Biological_Process  Biological_Process: Regulation Of Centrosome C...
# 6  Biological_Process  Biological_Process: Regulation Of Centrosome D...
# 2  Molecular_Function  Molecular_Function: Protein Serine/Threonine K...
# 6  Molecular_Function  Molecular_Function: DNA Secondary Structure Bi...
#
#   Overlap  P-value  Adjusted P-value Old P-value Old Adjusted P-value  \
# 0     1/5  0.00025          0.002550           0                    0
# 0     1/5  0.00025          0.000900           0                    0
# 1     1/6  0.00030          0.000900           0                    0
# 2     1/7  0.00035          0.000900           0                    0
# 3     1/8  0.00040          0.000900           0                    0
# 4     1/9  0.00045          0.000900           0                    0
# 0    1/10  0.00050          0.007650           0                    0
# 0    1/10  0.00050          0.001200           0                    0
# 2    1/11  0.00055          0.002550           0                    0
# 1    1/11  0.00055          0.002550           0                    0
# 1    1/12  0.00060          0.001200           0                    0
# 0    1/13  0.00065          0.001300           0                    0
# 3    1/14  0.00070          0.002550           0                    0
# 5    1/16  0.00080          0.001333           0                    0
# 4    1/17  0.00085          0.002550           0                    0
# 1    1/18  0.00090          0.007650           0                    0
# 5    1/23  0.00115          0.002875           0                    0
# 6    1/31  0.00155          0.003321           0                    0
# 2    1/32  0.00160          0.002133           0                    0
# 6    1/33  0.00165          0.002357           0                    0
#
#    Odds Ratio  Combined Score Genes       factor
# 0     19995.0   165840.178437  GEN1  Micro:PCA_0
# 0     19995.0   165840.178437  GEN1  Micro:PCA_0
# 1     19994.0   162186.518632  GEN1  Micro:PCA_0
# 2     19993.0   159096.448716  GEN1  Micro:PCA_0
# 3     19992.0   156418.911417  GEN1  Micro:PCA_0
# 4     19991.0   154056.469240  GEN1  Micro:PCA_0
# 0     19990.0   151942.590868  ROS1    ExN:NMF_3
# 0     19990.0   151942.590868  PKIA  Astro:PCA_0
# 2     19989.0   150029.821029  GEN1  Micro:PCA_0
# 1     19989.0   150029.821029  GEN1  Micro:PCA_0
# 1     19988.0   148283.119629  PKIA  Astro:PCA_0
# 0     19987.0   146675.876168  PKIA  Astro:PCA_0
# 3     19986.0   145187.405357  GEN1  Micro:PCA_0
# 5     19984.0   142504.366779  GEN1  Micro:PCA_0
# 4     19983.0   141285.765837  GEN1  Micro:PCA_0
# 1     19982.0   140136.548441  ROS1    ExN:NMF_3
# 5     19977.0   135204.639223  GEN1  Micro:PCA_0
# 6     19969.0   129189.850988  GEN1  Micro:PCA_0
# 2     19968.0   128549.419558  PKIA  Astro:PCA_0
# 6     19967.0   127928.560316  GEN1  Micro:PCA_0

# %% [markdown]
# ### save the GSEA Enrichments detected

# %%
sig_results.to_csv(results_file)

# %%
# !date
