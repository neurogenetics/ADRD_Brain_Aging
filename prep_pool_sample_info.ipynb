# %% [markdown]
# ## Notebook to prep info for Pools and Samples

# %%
# !date
# Out:
# Sat Jul 17 18:35:19 EDT 2021

# %% [markdown]
# #### import libraries and set notebook variables

# %%
import pandas as pd

# %%
# naming
cohort = 'aging'

# directories
home_dir = '/labshare/raph/datasets/adrd_neuro'
wrk_dir = f'{home_dir}/{cohort}'
info_dir = f'{wrk_dir}/sample_info'

# in files
pool_file = f'{info_dir}/pool_info.csv'
sample_file = f'{info_dir}/patient_sample_info.csv'

# out files
info_file = f'{info_dir}/{cohort}.pool_patient_sample_info.csv'

# contants
bank_abbrs = {'NIMH Human Brain Collection Core': 'NHBCC', 
              'U. Pittsburgh Brain Tissue Donation Program': 'UPBTDP', 
              'U. Maryland Brain & Tissue Bank': 'UMBTB'}

# %% [markdown]
# #### read the input data files

# %%
pool_df = pd.read_csv(pool_file)
print(pool_df.shape)
display(pool_df.head())
# Out:
# (48, 3)
#   Pool_no Sample_no Sequence_type
# 0  POOL01  Aging111           RNA
# 1  POOL01  Aging095           RNA
# 2  POOL01  Aging080           RNA
# 3  POOL01  Aging088           RNA
# 4  POOL01  Aging099           RNA

# %%
sample_df = pd.read_csv(sample_file)
print(sample_df.shape)
# display(sample_df.head())
# Out:
# (118, 7)

# %% [markdown]
# #### for the Pool create pool name for the pool id

# %%
pool_df['pool_name'] = pool_df['Pool_no'].str.replace('POOL','').astype('int32').apply(lambda x: f'P{x:03d}')
print(pool_df.shape)
# display(pool_df.sample(10))
# Out:
# (48, 4)

# %% [markdown]
# #### for the sample id df create a donor id from the tissue bank and tissue bank source id

# %%
sample_df['donor_id'] = sample_df['Tissue_source'].apply(bank_abbrs.get) + '-' \
+ sample_df['Source_id'].astype('string')
print(sample_df.shape)
display(sample_df.sample(10))
# Out:
# (118, 8)
#    Sample_id  Source_id                                Tissue_source  \
# 60  Aging061       2521             NIMH Human Brain Collection Core
# 6   Aging007       2972             NIMH Human Brain Collection Core
# 94  Aging095       1604             NIMH Human Brain Collection Core
# 24  Aging025       5079              U. Maryland Brain & Tissue Bank
# 17  Aging018       2936             NIMH Human Brain Collection Core
# 16  Aging017       2936             NIMH Human Brain Collection Core
# 71  Aging072        831             NIMH Human Brain Collection Core
# 36  Aging037      13042  U. Pittsburgh Brain Tissue Donation Program
# 49  Aging050      13390  U. Pittsburgh Brain Tissue Donation Program
# 52  Aging053       1281             NIMH Human Brain Collection Core
#
#                            Brain_region Clinical_diagnosis   Age     Sex  \
# 60  Subgenual anterior cingulate cortex            Healthy  51.1    Male
# 6                       Locus coeruleus            Healthy  49.9    Male
# 94                Middle temporal gyrus            Healthy  27.2    Male
# 24                       Frontal cortex            Healthy  33.2    Male
# 17                        Raphe nucleus            Healthy  66.1  Female
# 16                      Locus coeruleus            Healthy  66.1  Female
# 71                  Subventricular zone            Healthy  85.2    Male
# 36                      Brodmann area 4            Healthy  46.0  Female
# 49                      Brodmann area 8            Healthy  33.0    Male
# 52  Subgenual anterior cingulate cortex            Healthy  24.9    Male
#
#         donor_id
# 60    NHBCC-2521
# 6     NHBCC-2972
# 94    NHBCC-1604
# 24    UMBTB-5079
# 17    NHBCC-2936
# 16    NHBCC-2936
# 71     NHBCC-831
# 36  UPBTDP-13042
# 49  UPBTDP-13390
# 52    NHBCC-1281

# %% [markdown]
# #### merge into info data frame using Aging Sample_id

# %%
info_df = pool_df.merge(sample_df, how='inner', left_on='Sample_no', right_on='Sample_id')
print(info_df.shape)
display(info_df.sample(10))
# Out:
# (48, 12)
#    Pool_no Sample_no Sequence_type pool_name Sample_id  Source_id  \
# 30  POOL04  Aging104           RNA      P004  Aging104       1615
# 19  POOL03  Aging090           RNA      P003  Aging090       1340
# 45  POOL06  Aging102           RNA      P006  Aging102       1613
# 37  POOL05  Aging072           RNA      P005  Aging072        831
# 2   POOL01  Aging080           RNA      P001  Aging080       1187
# 7   POOL01  Aging073           RNA      P001  Aging073       1119
# 3   POOL01  Aging088           RNA      P001  Aging088       1340
# 27  POOL04  Aging089           RNA      P004  Aging089       1340
# 15  POOL02  Aging105           RNA      P002  Aging105       1615
# 9   POOL02  Aging076           RNA      P002  Aging076       1137
#
#                        Tissue_source           Brain_region  \
# 30  NIMH Human Brain Collection Core      Entorhinal cortex
# 19  NIMH Human Brain Collection Core                Putamen
# 45  NIMH Human Brain Collection Core    Subventricular zone
# 37  NIMH Human Brain Collection Core    Subventricular zone
# 2   NIMH Human Brain Collection Core  Middle temporal gyrus
# 7   NIMH Human Brain Collection Core  Middle temporal gyrus
# 3   NIMH Human Brain Collection Core  Middle temporal gyrus
# 27  NIMH Human Brain Collection Core      Entorhinal cortex
# 15  NIMH Human Brain Collection Core                Putamen
# 9   NIMH Human Brain Collection Core  Middle temporal gyrus
#
#    Clinical_diagnosis   Age     Sex    donor_id
# 30            Healthy  71.8  Female  NHBCC-1615
# 19            Healthy  26.2  Female  NHBCC-1340
# 45            Healthy  78.0    Male  NHBCC-1613
# 37            Healthy  85.2    Male   NHBCC-831
# 2             Healthy  21.5  Female  NHBCC-1187
# 7             Healthy  64.3  Female  NHBCC-1119
# 3             Healthy  26.2  Female  NHBCC-1340
# 27            Healthy  26.2  Female  NHBCC-1340
# 15            Healthy  71.8  Female  NHBCC-1615
# 9             Healthy  68.6    Male  NHBCC-1137

# %% [markdown]
# #### save the merged info files

# %%
info_df.to_csv(info_file, index=False)
