# %% [markdown]
# ## Notebook to attempt to visualize the age analyses resutls as a heatmap

# %%
# !date
# Out:
# Wed Mar 30 18:00:01 EDT 2022

# %% [markdown]
# #### import libraries and set notebook variables

# %%
from pandas import read_csv, pivot
from seaborn import clustermap
import matplotlib.pyplot as plt
from matplotlib.pyplot import rc_context

# %matplotlib inline
# for white background of figures (only for docs rendering)
# %config InlineBackend.print_figure_kwargs={'facecolor' : "w"}
# %config InlineBackend.figure_format='retina'

# %%
# parameters
cohort = 'aging'
assay = 'RNA'

# directories for initial setup
home_dir = '/labshare/raph/datasets/adrd_neuro'
wrk_dir = f'{home_dir}/{cohort}'
results_dir = f'{wrk_dir}/results'

# in files
results_file = f'{results_dir}/{cohort}.glmmtmb_age_diffs.csv'

# out file

# constants
debug = True

# %% [markdown]
# #### load the results to include in the figure

# %%
# %%time
results_df = read_csv(results_file)
print(results_df.shape)
if debug:
    display(results_df.head())
# Out:
# (299534, 9)
#       feature  intercept  estimate  std.error  statistic   p.value  \
# 0  AL627309.1  -3.532232  0.437769   0.198571   2.204596  0.027482
# 1  AL627309.5  -2.466935  0.233767   0.148533   1.573841  0.115524
# 2  AC114498.1  -9.307264  2.061367   1.253926   1.643931  0.100191
# 3  AL669831.2  -5.156279 -0.736573   0.344991  -2.135051  0.032757
# 4   LINC01409  -0.621747  0.135679   0.155248   0.873948  0.382147
#
#                   tissue          type    fdr_bh
# 0  Middle temporal gyrus  brain_region  0.123209
# 1  Middle temporal gyrus  brain_region  0.265975
# 2  Middle temporal gyrus  brain_region  0.245341
# 3  Middle temporal gyrus  brain_region  0.134740
# 4  Middle temporal gyrus  brain_region  0.549119
# CPU times: user 343 ms, sys: 35.1 ms, total: 378 ms
# Wall time: 377 ms

# %% [markdown]
# #### need to reformat results table to proper contents and shape for us with clustermap

# %% [markdown]
# #### subset to desired result set type

# %%
results_df.type.value_counts()
# Out:
# cell_type       157572
# broad_type       75738
# brain_region     66224
# Name: type, dtype: int64

# %%
this_type = 'cell_type'
result_set_df = results_df.loc[results_df.type == this_type]
print(result_set_df.shape)
if debug:
    display(result_set_df.head())
# Out:
# (157572, 9)
#           feature  intercept  estimate  std.error  statistic   p.value  \
# 66224  AL627309.5  -2.184424  0.238745   0.112574   2.120777  0.033941
# 66225   LINC01409  -0.156989 -0.040181   0.054000  -0.744101  0.456815
# 66226       NOC2L  -1.060869 -0.107795   0.099441  -1.084014  0.278359
# 66227      KLHL17  -2.886849  0.218999   0.258417   0.847464  0.396737
# 66228       ISG15  -3.151931 -0.463629   0.202407  -2.290578  0.021988
#
#                tissue       type    fdr_bh
# 66224  ExN CUX2 LAMP5  cell_type  0.137298
# 66225  ExN CUX2 LAMP5  cell_type  0.615619
# 66226  ExN CUX2 LAMP5  cell_type  0.449901
# 66227  ExN CUX2 LAMP5  cell_type  0.562456
# 66228  ExN CUX2 LAMP5  cell_type  0.110181

# %% [markdown]
# #### what tissue results are present in this result type

# %%
result_set_df.tissue.value_counts()
# Out:
# InN ADARB2 VIP       12338
# ExN CUX2 LAMP5       11613
# ExN RORB THEMIS      10836
# ExN CUX2 ADARB2      10789
# SPN D1               10249
# InN LHX6 PVALB       10040
# SPN D2                9828
# ExN FEZF2             9291
# Oligodendrocyte-1     7925
# InN LHX6 SST          7768
# ExN RORB              7340
# Astrocyte             6629
# InN ADARB2 LAMP5      6438
# Oligodendrocyte-2     6323
# SPN D1-2              5564
# Ependymal             4601
# OPC                   4275
# Microglia             4236
# ExN THEMIS            3643
# Mural                 2220
# SPN D2-2              2056
# Endothelial           1242
# Oligodendrocyte-3     1180
# ExN LAMP5             1148
# Name: tissue, dtype: int64

# %% [markdown]
# #### can use pandas pivot to reformat results into desired shape, of result value (rows) per gene per category type (cols)

# %%
# fig_df = result_set_df.pivot(index='feature', columns='tissue')['estimate']
fig_df = result_set_df.pivot(index='feature', columns='tissue')['statistic']
print(fig_df.shape)
if debug:
    display(fig_df.head())
# Out:
# (22263, 24)
# tissue    Astrocyte  Endothelial  Ependymal  ExN CUX2 ADARB2  ExN CUX2 LAMP5  \
# feature
# A1BG            NaN          NaN        NaN              NaN             NaN
# A1BG-AS1        NaN          NaN   1.375891        -0.760938       -0.473010
# A1CF            NaN          NaN        NaN              NaN             NaN
# A2M             NaN    -1.465672        NaN              NaN       -0.622028
# A2M-AS1         NaN          NaN        NaN              NaN             NaN
#
# tissue    ExN FEZF2  ExN LAMP5  ExN RORB  ExN RORB THEMIS  ExN THEMIS  ...  \
# feature                                                                ...
# A1BG            NaN        NaN -1.791795        -1.233536         NaN  ...
# A1BG-AS1        NaN        NaN       NaN              NaN         NaN  ...
# A1CF            NaN        NaN       NaN        -2.321872         NaN  ...
# A2M       -1.870989        NaN       NaN        -1.556805   -0.918974  ...
# A2M-AS1         NaN        NaN       NaN              NaN         NaN  ...
#
# tissue    Microglia  Mural       OPC  Oligodendrocyte-1  Oligodendrocyte-2  \
# feature
# A1BG            NaN    NaN       NaN                NaN                NaN
# A1BG-AS1        NaN    NaN       NaN          -0.987874                NaN
# A1CF            NaN    NaN       NaN                NaN                NaN
# A2M        1.421374    NaN -4.678564                NaN          -1.634996
# A2M-AS1         NaN    NaN -2.877900          -1.799196                NaN
#
# tissue    Oligodendrocyte-3    SPN D1  SPN D1-2    SPN D2  SPN D2-2
# feature
# A1BG                    NaN       NaN       NaN       NaN       NaN
# A1BG-AS1                NaN -1.645575       NaN  0.472180       NaN
# A1CF                    NaN       NaN       NaN       NaN       NaN
# A2M                     NaN -0.280425       NaN -0.081806       NaN
# A2M-AS1                 NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# #### need to fill missing with no effect; ie 0. missing was likely the result of untestable in the tissue if full results files was loaded

# %%
fig_df.fillna(0, inplace=True)
print(fig_df.shape)
if debug:
    display(fig_df.head())
# Out:
# (22263, 24)
# tissue    Astrocyte  Endothelial  Ependymal  ExN CUX2 ADARB2  ExN CUX2 LAMP5  \
# feature
# A1BG            0.0     0.000000   0.000000         0.000000        0.000000
# A1BG-AS1        0.0     0.000000   1.375891        -0.760938       -0.473010
# A1CF            0.0     0.000000   0.000000         0.000000        0.000000
# A2M             0.0    -1.465672   0.000000         0.000000       -0.622028
# A2M-AS1         0.0     0.000000   0.000000         0.000000        0.000000
#
# tissue    ExN FEZF2  ExN LAMP5  ExN RORB  ExN RORB THEMIS  ExN THEMIS  ...  \
# feature                                                                ...
# A1BG       0.000000        0.0 -1.791795        -1.233536    0.000000  ...
# A1BG-AS1   0.000000        0.0  0.000000         0.000000    0.000000  ...
# A1CF       0.000000        0.0  0.000000        -2.321872    0.000000  ...
# A2M       -1.870989        0.0  0.000000        -1.556805   -0.918974  ...
# A2M-AS1    0.000000        0.0  0.000000         0.000000    0.000000  ...
#
# tissue    Microglia  Mural       OPC  Oligodendrocyte-1  Oligodendrocyte-2  \
# feature
# A1BG       0.000000    0.0  0.000000           0.000000           0.000000
# A1BG-AS1   0.000000    0.0  0.000000          -0.987874           0.000000
# A1CF       0.000000    0.0  0.000000           0.000000           0.000000
# A2M        1.421374    0.0 -4.678564           0.000000          -1.634996
# A2M-AS1    0.000000    0.0 -2.877900          -1.799196           0.000000
#
# tissue    Oligodendrocyte-3    SPN D1  SPN D1-2    SPN D2  SPN D2-2
# feature
# A1BG                    0.0  0.000000       0.0  0.000000       0.0
# A1BG-AS1                0.0 -1.645575       0.0  0.472180       0.0
# A1CF                    0.0  0.000000       0.0  0.000000       0.0
# A2M                     0.0 -0.280425       0.0 -0.081806       0.0
# A2M-AS1                 0.0  0.000000       0.0  0.000000       0.0
#
# [5 rows x 24 columns]

# %% [markdown]
# #### subset full results to gene set to use for plotting

# %%
# this is crude brute looping
gene_set = {}
for tissue in fig_df.columns:
    print(tissue)
    temp = fig_df.sort_values(tissue, ascending=False)
    top5pos = temp.head(5)
    top5pos = top5pos.loc[top5pos[tissue] > 0]
    top5neg = temp.tail(5)
    top5neg = top5neg.loc[top5neg[tissue] < 0]
    # display(top5pos.head())
    # display(top5neg.tail())
    tissue_genes = set(top5pos.index) | set(top5neg.index)
    gene_set = set(gene_set) | tissue_genes
    print(tissue_genes)    
    
print(len(gene_set))
print(gene_set)
# Out:
# Astrocyte
# {'HLA-A', 'B4GAT1', 'COX6C', 'EGF', 'GMPR', 'WNT5B', 'TNFRSF11B', 'KCNK1', 'AC024257.1', 'TNS2'}
# Endothelial
# {'TUSC3', 'CP', 'SERTAD2', 'TMEM132C', 'NPAS2', 'ID1', 'MBOAT2', 'THRB', 'TGM2', 'SLC11A2'}
# Ependymal
# {'GLIPR1L2', 'KCND3', 'LINC02021', 'ACTR3B', 'AC092802.1', 'TMTC2', 'RGS20', 'ACTB', 'VCL', 'DOCK5'}
# ExN CUX2 ADARB2
# {'TUSC3', 'TGM3', 'RORB', 'CELSR1', 'SLC35F4', 'SOX9-AS1', 'MYRFL', 'ATP8A1', 'RABEPK', 'PRDM5'}
# ExN CUX2 LAMP5
# {'KIF13B', 'ALS2CL', 'CALCOCO2', 'LINC01151', 'AC095060.1', 'HIP1', 'LINC02237', 'SERPINB6', 'UACA', 'IL12A-AS1'}
# ExN FEZF2
# {'RHBDL3', 'NR3C2', 'LINC00907', 'DOC2B', 'AC034195.1', 'AL590807.1', 'SLC38A11', 'LINC00378', 'CNBD1', 'MTAP'}
# ExN LAMP5
# {'NECAB1', 'LRRC4C', 'SLC8A1', 'CCBE1', 'AL024495.1', 'CUX2', 'ADARB2', 'TCERG1L', 'SPON1', 'ELAVL2'}
# ExN RORB
# {'RHBDL3', 'RIMS2', 'PKD1L1', 'GRIN2B', 'AC093610.1', 'HHAT', 'ARHGAP10', 'P2RY6', 'DNM3', 'ITGA9'}
# ExN RORB THEMIS
# {'PRDM2', 'CCND3', 'ELFN2', 'RHBDL3', 'NR3C2', 'MIR31HG', 'L3MBTL4', 'RXRG', 'CNBD1', 'MTAP'}
# ExN THEMIS
# {'SPTBN4', 'SYN3', 'GALNT9', 'PLEKHA6', 'AC079793.1', 'NRXN3', 'FGF2', 'CADPS', 'ARPP21', 'LINC00632'}
# InN ADARB2 LAMP5
# {'BAALC-AS1', 'AC010974.2', 'CCDC144A', 'DDN', 'IL1RAP', 'MKRN3', 'TMEM59L', 'UNC13C', 'PCDH9', 'AC016587.1'}
# InN ADARB2 VIP
# {'CCDC85B', 'NAAA', 'ALDH1L1', 'STK31', 'AP001407.1', 'ADGRL3-AS1', 'SH3D19', 'DNAJB11', 'HIP1', 'LINC00844'}
# InN LHX6 PVALB
# {'CCDC144A', 'FXYD7', 'AC034195.1', 'HES4', 'AC005252.4', 'LINC02112', 'RPS16', 'MYPN', 'TMEM120A', 'PSMB6'}
# InN LHX6 SST
# {'AC240274.1', 'CCDC144A', 'TCEA3', 'GRAMD2B', 'MIAT', 'AC034195.1', 'PCDHGA1', 'AC107223.1', 'ZNF827', 'SCARF2'}
# Microglia
# {'EML1', 'PAQR5', 'MAFB', 'IL15', 'TGFBR1', 'NREP', 'APBA2', 'CECR2', 'MS4A6A', 'C22orf34'}
# Mural
# {'HSD11B1', 'SRPX2', 'APOD', 'B4GALT6', 'VLDLR-AS1', 'SLC22A3', 'PMP22', 'AC119673.2', 'FREM1', 'PALM'}
# OPC
# {'LPL', 'PRKCA', 'NR6A1', 'CNR1', 'FAM66E', 'ABCC8', 'LINC01117', 'SEMA6D', 'AKNA', 'RHCG'}
# Oligodendrocyte-1
# {'ZNF624', 'CPB1', 'HIF1A', 'CSPG5', 'LURAP1L-AS1', 'SUMF1', 'AC034195.1', 'AL512625.1', 'DUXAP8', 'SEC23B'}
# Oligodendrocyte-2
# {'SLC44A1', 'CPB1', 'CPEB2', 'ADAMTS14', 'MAGI2', 'LURAP1L-AS1', 'AC034195.1', 'DUXAP8', 'SOWAHA', 'DUOXA1'}
# Oligodendrocyte-3
# {'AC007319.1', 'EDNRB', 'MAN1A2', 'CACNA1A', 'MAN1C1', 'POR', 'MAOB', 'ADAM19', 'ITGB4', 'PRKAG2'}
# SPN D1
# {'LINC01378', 'MKRN3', 'RALY', 'LINC00457', 'AC017002.5', 'NHSL1', 'MIR4435-2HG', 'U95743.1', 'THSD7B', 'KIF26B'}
# SPN D1-2
# {'KLF10', 'AC017101.1', 'RGS5', 'AC246817.1', 'NCOA1', 'SCN5A', 'ADGRB2', 'LINC02112', 'FAM157C', 'LINC00970'}
# SPN D2
# {'IFT172', 'MDH1B', 'DDX59', 'MKRN3', 'LINC02458', 'ZNF263', 'HEATR3', 'THSD7B', 'RTL5', 'PREX1'}
# SPN D2-2
# {'C2CD5', 'DRC3', 'GRIK1-AS1', 'SYTL5', 'ZNF680', 'SDK1', 'AL133346.1', 'LINC01277', 'MYT1L', 'GRIK1'}
# 220
# {'EML1', 'LINC00907', 'VCL', 'ITGB4', 'ITGA9', 'PCDH9', 'PRKAG2', 'DRC3', 'STK31', 'CP', 'CSPG5', 'IL15', 'POR', 'CALCOCO2', 'FGF2', 'AC119673.2', 'DNM3', 'TCERG1L', 'LINC01117', 'FAM157C', 'LINC00378', 'AC016587.1', 'KLF10', 'ALS2CL', 'AL024495.1', 'SOX9-AS1', 'LINC01151', 'MIR31HG', 'CACNA1A', 'UACA', 'B4GAT1', 'DDN', 'EGF', 'ALDH1L1', 'NR3C2', 'SERTAD2', 'IL1RAP', 'AC079793.1', 'DNAJB11', 'GRAMD2B', 'MAFB', 'SRPX2', 'PMP22', 'MAN1C1', 'AC095060.1', 'ATP8A1', 'RXRG', 'UNC13C', 'PRKCA', 'MDH1B', 'APOD', 'AP001407.1', 'GALNT9', 'PKD1L1', 'MIAT', 'GRIN2B', 'ARHGAP10', 'ZNF263', 'ZNF680', 'MYRFL', 'CADPS', 'LINC00970', 'RTL5', 'SOWAHA', 'PRDM5', 'PRDM2', 'BAALC-AS1', 'RHBDL3', 'NR6A1', 'MKRN3', 'ACTR3B', 'NRXN3', 'ABCC8', 'RALY', 'AC107223.1', 'THRB', 'AC024257.1', 'AC017101.1', 'CCDC85B', 'CCND3', 'CCDC144A', 'SPTBN4', 'B4GALT6', 'HIF1A', 'EDNRB', 'CELSR1', 'SLC22A3', 'TMEM132C', 'IFT172', 'GRIK1-AS1', 'CCBE1', 'SYTL5', 'TMEM59L', 'AC005252.4', 'MBOAT2', 'NHSL1', 'AKNA', 'KIF13B', 'NECAB1', 'NAAA', 'COX6C', 'RORB', 'SLC8A1', 'LINC00457', 'SUMF1', 'P2RY6', 'TGFBR1', 'AL512625.1', 'AL133346.1', 'LINC01277', 'SLC38A11', 'RPS16', 'MYPN', 'SERPINB6', 'SCARF2', 'IL12A-AS1', 'LPL', 'HLA-A', 'LRRC4C', 'DOC2B', 'NCOA1', 'HES4', 'FREM1', 'MYT1L', 'MTAP', 'ELAVL2', 'C2CD5', 'HSD11B1', 'ELFN2', 'TUSC3', 'TCEA3', 'TGM3', 'FAM66E', 'GMPR', 'ID1', 'AC093610.1', 'SCN5A', 'NREP', 'THSD7B', 'ARPP21', 'C22orf34', 'SPON1', 'PSMB6', 'PALM', 'KCND3', 'RGS5', 'DDX59', 'NPAS2', 'SLC35F4', 'AC017002.5', 'TNFRSF11B', 'L3MBTL4', 'ZNF827', 'SEC23B', 'LINC00632', 'CPEB2', 'VLDLR-AS1', 'MAN1A2', 'ADGRB2', 'APBA2', 'LINC02237', 'CECR2', 'ACTB', 'LINC00844', 'MS4A6A', 'CNBD1', 'GLIPR1L2', 'WNT5B', 'AC246817.1', 'AC034195.1', 'HHAT', 'PCDHGA1', 'LINC02112', 'AC092802.1', 'TGM2', 'PREX1', 'DUOXA1', 'CPB1', 'AC007319.1', 'AC240274.1', 'PAQR5', 'LINC02021', 'ADAMTS14', 'RIMS2', 'CNR1', 'MAGI2', 'CUX2', 'SDK1', 'TMTC2', 'SEMA6D', 'ADAM19', 'KIF26B', 'DUXAP8', 'TMEM120A', 'SYN3', 'FXYD7', 'ADGRL3-AS1', 'SH3D19', 'ADARB2', 'HEATR3', 'AL590807.1', 'U95743.1', 'KCNK1', 'SLC11A2', 'RHCG', 'GRIK1', 'SLC44A1', 'ZNF624', 'AC010974.2', 'LINC01378', 'PLEKHA6', 'LURAP1L-AS1', 'LINC02458', 'MIR4435-2HG', 'HIP1', 'RGS20', 'MAOB', 'RABEPK', 'TNS2', 'DOCK5'}

# %%
fig_df = fig_df.loc[fig_df.index.isin(gene_set)]
print(fig_df.shape)
if debug:
    display(fig_df.head())
# Out:
# (220, 24)
# tissue      Astrocyte  Endothelial  Ependymal  ExN CUX2 ADARB2  \
# feature
# ABCC8        0.000000          0.0        0.0         0.000000
# AC005252.4   0.000000          0.0        0.0         0.000000
# AC007319.1  -0.827055          0.0        0.0        -0.435641
# AC010974.2  -1.683624          0.0        0.0         0.000000
# AC016587.1   0.000000          0.0        0.0         0.000000
#
# tissue      ExN CUX2 LAMP5  ExN FEZF2  ExN LAMP5  ExN RORB  ExN RORB THEMIS  \
# feature
# ABCC8            -0.154067   2.188194        0.0       0.0         0.000000
# AC005252.4        0.000000   0.000000        0.0       0.0         0.000000
# AC007319.1       -1.671928  -1.608433        0.0       0.0        -0.683953
# AC010974.2       -1.349843  -1.823346        0.0       0.0        -2.825000
# AC016587.1        0.000000   0.000000        0.0       0.0         0.000000
#
# tissue      ExN THEMIS  ...  Microglia  Mural       OPC  Oligodendrocyte-1  \
# feature                 ...
# ABCC8         0.000000  ...        0.0    0.0  5.316305           0.892181
# AC005252.4    0.000000  ...        0.0    0.0  0.000000           0.000000
# AC007319.1   -0.692237  ...        0.0    0.0 -1.204501          -3.629240
# AC010974.2    0.000000  ...        0.0    0.0 -2.115362           1.446436
# AC016587.1    0.000000  ...        0.0    0.0  0.000000           0.000000
#
# tissue      Oligodendrocyte-2  Oligodendrocyte-3    SPN D1  SPN D1-2  \
# feature
# ABCC8               -1.650203           0.000000  0.000000  0.758400
# AC005252.4           0.000000           0.000000  0.000000  0.000000
# AC007319.1          -2.419129          -4.645647 -1.493599 -1.757242
# AC010974.2           2.929307           0.000000 -2.523020  0.000000
# AC016587.1           0.000000           0.000000  0.000000  0.000000
#
# tissue        SPN D2  SPN D2-2
# feature
# ABCC8       0.000000  0.000000
# AC005252.4  0.000000  0.000000
# AC007319.1 -0.799017 -1.419008
# AC010974.2 -3.563651  0.000000
# AC016587.1  0.000000  0.000000
#
# [5 rows x 24 columns]

# %%
with rc_context({'figure.figsize': (8, 8), 'figure.dpi': 100}):
    plt.style.use('seaborn-bright')
    clustermap(fig_df)

# %%
with rc_context({'figure.figsize': (8, 8), 'figure.dpi': 100}):
    plt.style.use('seaborn-bright')
    clustermap(fig_df, cmap='viridis')

# %%
with rc_context({'figure.figsize': (8, 8), 'figure.dpi': 100}):
    plt.style.use('seaborn-bright')
    clustermap(fig_df, cmap='vlag', col_cluster=True, row_cluster=True, dendrogram_ratio=0.1)

# %%
with rc_context({'figure.figsize': (8, 8), 'figure.dpi': 100}):
    plt.style.use('seaborn-bright')
    clustermap(fig_df.T, cmap='vlag', col_cluster=True, row_cluster=True, dendrogram_ratio=0.1)

# %%
# !date
# Out:
# Wed Mar 30 18:00:06 EDT 2022
